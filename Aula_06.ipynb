# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizSalvador-GIT/CP03-SERS/blob/main/Aula_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando bibliotecas

import pandas as pd
import numpy as np

# Gráficos

import matplotlib.pyplot as plt
import seaborn as sns

# Algoritimo de regressão linear

from sklearn.linear_model import LinearRegression

# Ferramenta para separação dos dados de treino e teste
# X_train, X_test, Y_train, Y_test

from sklearn.model_selection import train_test_split

# Avaliação
# Métricas de avaliação

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
# Carregamento do dataset

df = pd.read_csv('https://raw.githubusercontent.com/prof-atritiack/CHECKPOINT_02_1CCPH_SERS/refs/heads/main/Data_for_UCI_named.csv')
df.head()
